# %%
import json

# %%
with open('/home/jm/Desktop/Hack/NIHackTwistory/Twitter_API/Tweets_#maga.json') as f:
    for line in f:
        tweet = json.loads(line)

# %%
tweet
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Jun 09 10:06:53 +0000 2018',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 63578758,
#     'id_str': '63578758',
#     'indices': [3, 18],
#     'name': 'Sharika Soal',
#     'screen_name': 'LadyThriller69'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1005390770667483136,
#  'id_str': '1005390770667483136',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jun 05 10:17:03 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
# ...
